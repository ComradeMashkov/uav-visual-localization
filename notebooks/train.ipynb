# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.utils.check_cuda import check_cuda

check_cuda()
# Out:
# CUDA is ready. Using GPU: NVIDIA GeForce RTX 5070

# %%
from src.process_data.prepare_yolo import prepare

prepare()
# Out:
# Dataset split into train/val and saved to z:\dev\practice\uav-visual-localization\data\yolo_dataset
# Total images: 5041
# Used (with labels): 2367
# Skipped (no labels): 2674

# %%
from ultralytics import YOLO
import os

model = YOLO("yolo11s.pt")
yaml_path = os.path.join("..", "data", "data.yaml")

model.train(
    data=yaml_path,
    epochs=100,
    imgsz=640,
    batch=16,
    name="test_yolo_run"
)
# Out:
# ...
# 100%|██████████| 18.4M/18.4M [00:01<00:00, 10.3MB/s]
# Ultralytics 8.3.168  Python-3.12.10 torch-2.9.0.dev20250718+cu128 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %%
from IPython.display import Image, display

run_dir = "../runs/detect/test_yolo_run"

for fname in ["results.png", "train_batch0.jpg", "val_batch0_pred.jpg"]:
    fpath = os.path.join(run_dir, fname)
    if os.path.exists(fpath):
        print(f"✅ {fname}")
        display(Image(filename=fpath))
    else:
        print(f"❌ {fname} not found")
# Out:
# ✅ results.png
# ✅ train_batch0.jpg
# ✅ val_batch0_pred.jpg
